# %%
from turtle import pd
from .preprocessing import detect_door_events

df = detect_door_events(pd.DataFrame(data))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 from .preprocessing import detect_door_events
#       4 df = detect_door_events(pd.DataFrame(data))
#
# ModuleNotFoundError: No module named 'pandas'
